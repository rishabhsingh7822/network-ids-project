# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "import json\n",
    "from pathlib import Path\n",
    "\n",
    "BASE_DIR = Path('C:/Users/Rajesh/OneDrive/Desktop/network-ids-project')\n",
    "df = pd.read_parquet(BASE_DIR / 'data/processed/combined_clean.parquet')\n",
    "\n",
    "print(f'Shape: {df.shape}')\n",
    "print(f'Attack types:\\n{df[\"Label\"].value_counts()}')"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.11.0"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
